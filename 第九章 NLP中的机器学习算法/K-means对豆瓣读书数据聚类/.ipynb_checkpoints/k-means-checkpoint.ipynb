# %% [markdown]
# # what's new

# %%
'''
    ① pd.dataframe的某一列series可以转换成list，用tolist()函数
    ② 转化成特征矩阵的文本做聚类时，聚类的具体信息在clustering_obj.cluster_centers_.argsort()[:, ::-1]里
    三 book_data[book_data['Cluster'] == cluster_num]['title'].tolist()
    ④ [feature_names[index] for index in ordered_centroids[cluster_num, :topn_features]]
'''
def get_cluster_data(clustering_obj, book_data,
                     feature_names, num_clusters,
                     topn_features=10):
    cluster_details = {}
    # 获取cluster的center
    ordered_centroids = clustering_obj.cluster_centers_.argsort()[:, ::-1]
    # 获取每个cluster的关键特征
    # 获取每个cluster的书
    for cluster_num in range(num_clusters):
        cluster_details[cluster_num] = {}
        cluster_details[cluster_num]['cluster_num'] = cluster_num
        
        key_features = [feature_names[index]
                        for index
                        in ordered_centroids[cluster_num, :topn_features]]
        cluster_details[cluster_num]['key_features'] = key_features

        books = book_data[book_data['Cluster'] == cluster_num]['title'].tolist()
        cluster_details[cluster_num]['books'] = books

    return cluster_details

# %% [markdown]
# ### pd.csv读取数据，tolist()获取title,content

# %%
import pandas as pd
import numpy as np

# %%
'''
    用pd读取的文件，book_data类型就是dataframe格式
'''
book_data = pd.read_csv("./data/data.csv")
book_data.head()
# Out:
#     title         tag                                              info  \
# 0  ﻿解忧杂货店  豆瓣图书标签: 小说         [日] 东野圭吾 / 李盈春 / 南海出版公司 / 2014-5 / 39.50元
# 1   巨人的陨落  豆瓣图书标签: 小说  [英] 肯·福莱特 / 于大卫 / 江苏凤凰文艺出版社 / 2016-5-1 / 129.80元
# 2   我的前半生  豆瓣图书标签: 小说                     亦舒 / 新世界出版社 / 2007-8 / 22.00元
# 3    百年孤独  豆瓣图书标签: 小说   [哥伦比亚] 加西亚·马尔克斯 / 范晔 / 南海出版公司 / 2011-6 / 39.50元
# 4   追风筝的人  豆瓣图书标签: 小说     [美] 卡勒德·胡赛尼 / 李继宏 / 上海人民出版社 / 2006-5 / 29.00元
#
#       comments                                            content
# 0  (225675人评价)  现代人内心流失的东西，这家杂货店能帮你找回——\r\n僻静的街道旁有一家杂货店，只要写下烦恼...
# 1   (22536人评价)  在第一次世界大战的硝烟中，每一个迈向死亡的生命都在热烈地生长——威尔士的矿工少年、刚失恋的美...
# 2   (20641人评价)  一个三十几岁的美丽女人子君，在家做全职家庭主妇。却被一个平凡女人夺走丈夫，一段婚姻的失败，让...
# 3  (111883人评价)  《百年孤独》是魔幻现实主义文学的代表作，描写了布恩迪亚家族七代人的传奇故事，以及加勒比海沿岸...
# 4  (278905人评价)  12岁的阿富汗富家少爷阿米尔与仆人哈桑情同手足。然而，在一场风筝比赛后，发生了一件悲惨不堪的...

# %%
'''
    dataframe格式的数据的某一列series可以转化成list，tolist()
'''
book_titles = book_data["title"].tolist()
book_content = book_data["content"].tolist()
print(len(book_titles))
print("书名:", book_titles[0])
print("内容:", book_content[0])
# Out:
# 2822
# 书名: ﻿解忧杂货店
# 内容: 现代人内心流失的东西，这家杂货店能帮你找回——
# 僻静的街道旁有一家杂货店，只要写下烦恼投进卷帘门的投信口，第二天就会在店后的牛奶箱里得到回答。
# 因男友身患绝...

# %% [markdown]
# ### content去换行符，分词

# %%
import jieba

def normalize_corpus(corpus):
    normalized_corpus = []
    for text in corpus:
        text =" ".join(jieba.lcut(text.strip().replace("\r\n", "")))
        normalized_corpus.append(text)
    return normalized_corpus

norm_book_content = normalize_corpus(book_content)

# %%
norm_book_content[0]
# Out:
# '现代人 内心 流失 的 东西 ， 这家 杂货店 能 帮 你 找回 — — 僻静 的 街道 旁有 一家 杂货店 ， 只要 写下 烦恼 投进 卷帘门 的 投 信口 ， 第二天 就 会 在 店 后 的 牛奶箱 里 得到 回答 。 因 男友 身患 绝 ...'

# %% [markdown]
# ### 词频或tfidf提取文本特征

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

def build_feature_matrix(documents, feature_type='frequency', ngram_range=(1,1), min_df=0.0, max_df=1.0):
    feature_type = feature_type.lower().strip()
    
    if feature_type == "bianary":
        vectorizer = CountVectorizer(binary=True, max_df=max_df, ngram_range=ngram_range)
        
    elif feature_type == "frequency":
        vectorizer = CountVectorizer(binary=False, min_df=min_df, max_df=max_df, ngram_range=ngram_range)
    
    elif feature_type == "tfidf":
        vectorizer = TfidfVectorizer()
    else:
        raise Exception("Wrong feature type entered. Possible values: 'binary', 'frequency', 'tfidf'")
    
    feature_matrix = vectorizer.fit_transform(documents).astype(float)
    
    return vectorizer, feature_matrix

# %% [markdown]
# ### content分词后的结果，用tfidf，控制最小/最大词频比例，使用一元/二元语言模型获取特征矩阵

# %%
# 提取tfidf特征
vectorizer, feature_matrix = build_feature_matrix(norm_book_content, feature_type="tfidf",
                                                 min_df=0.2, max_df=0.9, ngram_range=(1,2))
# 查看特征数
print(feature_matrix.shape)
# Out:
# (2822, 16284)

# %%
# 获取前十个特征名字
feature_names = vectorizer.get_feature_names()
print(len(feature_names))
print(feature_names[888])
# Out:
# 16284
# 一条

# %% [markdown]
# ### 定义kmeans模型，训练集已经是矩阵形式，文本数*特征数

# %%
from sklearn.cluster import KMeans

def k_means(feature_matrix, num_clusters=10): # 聚10个类，迭代10000次
    km = KMeans(n_clusters=num_clusters,
                max_iter=10000)
    km.fit(feature_matrix)
    clusters = km.labels_
    return km, clusters # 返回聚类模型 和 聚类的lables,即是属于10个类别中的哪一个

# %%
num_clusters = 10
km_obj, clusters = k_means(feature_matrix=feature_matrix,
                           num_clusters=num_clusters)
book_data['Cluster'] = clusters # 2822个文本，每个文本对应的10个分类中的哪一个

# %%
len(clusters)
# Out:
# 2822

# %%
# 获取每个cluster的数量
from collections import Counter
c = Counter(clusters)
print(c.items())
# Out:
# dict_items([(0, 914), (2, 325), (3, 267), (9, 241), (6, 207), (5, 185), (8, 193), (1, 114), (4, 217), (7, 159)])

# %% [markdown]
# ## tessssssssssssssssssst

# %%
print("Top terms per cluster:")
order_centroids = km_obj.cluster_centers_.argsort()[:, ::-1]
terms = vectorizer.get_feature_names()
for i in range(10):
    print("Cluster %d:" % i, end='')
    for ind in order_centroids[i, :15]:
        print(' %s' % terms[ind], end='')
    print()
# Out:
# Top terms per cluster:
# Cluster 0: 本书 一本 the 不是 出版 读者 可以 作品 日本 如何 美国 世界 收录 自己 成为
# Cluster 1: 设计 用户 体验 交互 产品 本书 web 心理学 系统 简单 应用 设计师 进行 有时 梅琼译
# Cluster 2: 一个 我们 没有 自己 女人 就是 为什么 时代 不同 美国 一样 哈利 陌生 生命 美丽
# Cluster 3: 历史 一部 小说 金庸 世界 研究 作品 本书 古龙 作者 之一 中国 美国 关于 系列
# Cluster 4: 生活 人生 了解 自己 张爱玲 一个 本书 散文 日子 汪曾祺 重要 他们 唯一 马斯克 以及
# Cluster 5: 数学 内容 介绍 包括 理论 本书 涉及 主要 通信 应用 神经网络 原理 技术 方法 广泛
# Cluster 6: 艺术 编辑 推荐 漫画 畅销 小说 图像 法国 经典 哲学 欧洲 时代 水彩 艺术史 作品
# Cluster 7: 作者 商业 企业 isbn 三十年 写作 本书 记述 年间 变革 管理 图书 力作 30 20
# Cluster 8: 中国 著名 建筑 本书 公司 社会 出版 文化 先生 政治 作家 古代 学者 互联网 著作
# Cluster 9: 故事 讲述 真实 一个 生活 本书 三毛 小说 那些 自己 人物 作者 这是 如果 一部

# %%
# 10 * 16284
km_obj.cluster_centers_.argsort()[:, ::-1]
# Out:
# array([[ 9455,   884,   665, ...,  6980,  6981,  5939],
#        [14027, 11344,  2549, ..., 10732, 10731,     0],
#        [  741,  7912, 10270, ..., 10293, 10292,     0],
#        ...,
#        [ 2617,  4886,  2391, ..., 10580, 10579,     0],
#        [ 1560, 13529,  7107, ..., 10558, 10557,     0],
#        [ 8610, 13996, 11718, ..., 10458, 10457,  8141]])

# %%
'''
    argsort()将函数中的数据进行大小排序，然后按照其索引进行从小到大排序
'''
from numpy import *
a = [-9,0,3,-4,8,10]
print(argsort(a))
# Out:
# [0 3 1 2 4 5]

# %%
data = pd.DataFrame([["嗯啊", "嗯啊嗯啊嗯啊"],
                   ["不好", "真的不好"],
                    ["你好", "你真的好吗"]],columns = ["title", "content"])
data
# Out:
#   title content
# 0    嗯啊  嗯啊嗯啊嗯啊
# 1    不好    真的不好
# 2    你好   你真的好吗

# %%
data['title'].tolist()
# Out:
# ['嗯啊', '不好', '你好']

# %%
data[data["content"]=="真的不好"]['title'].tolist()
# Out:
# ['不好']

# %% [markdown]
# ## tessssssssssssssssssst

# %% [markdown]
# ### m模型的cluster_centers_属性，返回的是10×16284二维数组，簇数*特征数
# ### rgsort()将数按从小到大排序，输出索引
# ### [:,  ::-1] 二维数组的行全输出，列倒序输出，就是把上一步特征值最大的在最前输出

# %%
def get_cluster_data(clustering_obj, book_data,
                     feature_names, num_clusters,
                     topn_features=10):
    cluster_details = {}
    # 获取cluster的center
    ordered_centroids = clustering_obj.cluster_centers_.argsort()[:, ::-1]
    # 获取每个cluster的关键特征
    # 获取每个cluster的书
    for cluster_num in range(num_clusters):
        cluster_details[cluster_num] = {}
        cluster_details[cluster_num]['cluster_num'] = cluster_num
        
        key_features = [feature_names[index]
                        for index
                        in ordered_centroids[cluster_num, :topn_features]]
        cluster_details[cluster_num]['key_features'] = key_features

        books = book_data[book_data['Cluster'] == cluster_num]['title'].tolist()
        cluster_details[cluster_num]['books'] = books

    return cluster_details

# %%
cluster_data = get_cluster_data(clustering_obj=km_obj,
                                book_data=book_data,
                                feature_names=feature_names,
                                num_clusters=num_clusters,
                                topn_features=5
                               )
for i,j in cluster_data.items():
    print(i,j)
    print("*********************************")
# Out:
# 0 {'cluster_num': 0, 'key_features': ['本书', '一本', 'the', '不是', '出版'], 'books': ['\ufeff解忧杂货店', '新名字的故事', '世界的凛冬', '活着', '新名字的故事', '世界的凛冬', '我的天才女友', '世界的凛冬', '活着', '时间的果', '下雨天一个人在家', '吃鲷鱼让我打嗝', '当我谈跑步时我谈些什么', '孤独六讲', '\ufeff活着', '爱你就像爱生命', '时间的果', '一只特立独行的猪', '世界的凛冬', '恋情的终结', '\ufeff解忧杂货店', '东京本屋', '人间失格', '百鬼夜行 阳', '金色梦乡', '下雨天一个人在家', '强风吹拂', '火花', '1Q84 BOOK 1', '时间的果', '我口袋里的星辰如沙砾', '悲伤与理智', '孩子你慢慢来', '一个人的村庄', '所谓好玩的事，我再也不做了', '1Q84 BOOK 1', '当我谈跑步时我谈些什么', '没有色彩的多崎作和他的巡礼之年', '1Q84 BOOK 2', '且听风吟', '大萝卜和难挑的鳄梨', '国境以南 太阳以西', '远方的鼓声', '舞！舞！舞！', '没有女人的男人们', '1Q84 BOOK 3', '奇鸟行状录', '东京奇谭集', '鲍勃·迪伦诗歌集 (1961-2012)', '万物静默如谜', '我的孤独是一座花园', '海子诗全集', '博尔赫斯诗选', '唯有孤独恒常如新', '飞鸟集', '二十首情诗与绝望的歌', '二十亿光年的孤独', '荒原', '王尔德童话', '夜莺与玫瑰', '猜猜我有多爱你', '七夜物语', '牧羊少年奇幻之旅', '失物之书', '银河铁道之夜', '小毛驴与我', '狐狸的窗户', '一只特立独行的猪', '爱你就像爱生命', '我的精神家园', '王小波全集', '理想国与哲人王', '假如你愿意你就恋爱吧', '似水流年', '黑铁时代', '寻找无双·东宫西宫', '一只特立独行的猪', '我的精神家园', '王小波全集', '常识', '退步集', '野火集', '门萨的娼妓', '理想国与哲人王', '这就是二十四节气', '猜猜我有多爱你', '七夜物语', '梦书之城', '《噼里啪啦系列》', '深夜小狗神秘事件', '诗经', '东京梦华录', '声律启蒙', '既见君子', '\ufeff活着', '现实一种', '兄弟（下）', '音乐影响了我的写作', '温暖和百感交集的旅程', '余华作品系列（共12册）', '我能否相信自己', '黄昏里的男孩', '我胆小如鼠', '\ufeff半生缘', '张爱玲文集', '雷峰塔', '传奇', '阿城精选集', '额尔古纳河右岸', '望春风', '棋王.樹王.孩子王', '蒙着眼睛的旅行者', '城门开', '管锥编（全五册）', '七缀集', '宋诗选注', '钱锺书英文文集', '钱锺书手稿集•外文笔记（第一辑）', '茶花女', '安娜·卡列尼娜（上下）', '堂吉诃德', '丧钟为谁而鸣', '鲁迅全集（2005最新修订版）', '朝花夕拾', '狂人日记', '野草', '彷徨', '中国小说史略', '鲁迅杂文全集', '两地书', '鲁迅小说全集', '诗经', '东京梦华录', '声律启蒙', '既见君子', '心灵的焦灼', '斯·茨威格中短篇小说选', '巴西：未来之国', '变形的陶醉', '不朽', '无知', '慢', '告别圆舞曲', '雅克和他的主人', '抵挡太平洋的堤坝', '爱', '夏夜十点半钟', '玛格丽特·杜拉斯', '\ufeff生死桥', '树犹如此', '夏宇詩集／Salsa', '東課樓經變', '周夢蝶詩文集', '七声', '無愛紀', '她是女子，我也是女子', '简媜散文', '我城', '荒人手记', '寂寞的十七岁', '\ufeff疯狂艺术史：从达芬奇到伦勃朗', '切尔诺贝利之花', '伊甸园世界01：星之上', '海贼王', '金色梦乡', '长夜难明', '明镜之书', '夏日启示录', 'ZOO', '活了100万次的猫', '猜猜我有多爱你', 'Yaxin, le faune Gabriel', '你看起来好像很好吃', '睡不着：Tango一日一画', '阿狸·梦之城堡', '我口袋里的星辰如沙砾', '朝花惜时', '陪安东尼度过漫长岁月', '何以笙箫默', '致我们终将逝去的青春', '\ufeff解忧杂货店', '新参者', '时生', '雪地殺機', '圣女的救济', '伽利略的苦恼', '虚无的十字架', '拉普拉斯的魔女', '流星之绊', '超·杀人事件', '\ufeff三体', '你一生的故事', '三体Ⅱ', '火星救援', '华氏451', '摩天楼', '软件体的生命周期', '何以笙箫默', '岛屿之书', '鹤唳华亭', '夜旅人', '海棠依舊: 知否? 知否? 應是綠肥紅瘦 卷一', '三生三世 枕上书', '四月间事', '七根凶简', '长夜难明', '明镜之书', '锦衣行', '有匪2：离恨楼', '七夜雪', '刀背藏身', '剑桥倚天屠龙史', '碟形世界：猫和少年魔笛手', '美国众神', '冰与火之歌', '九州·缥缈录', '精灵宝钻', '有顶天家族', '\ufeff散步去', '海贼王', '大叔上等', '机器猫哆啦A梦23', '浪客行 1', '非法侵入(01)', '死亡筆記 1', '竹光侍 1', '天是红河岸', '20世紀少年01', '我可以被擁抱嗎？因為太過寂寞而叫了蕾絲邊應召', 'PRIDE', '我所理解的生活', '他的国', '光明与磊落', '青春', '长安乱', '一座城池', '很高兴见到你', '所有人问所有人', '零下一度', '杂的文', '韩寒五年文集（上下）', '飄移中國', '桃花债 上', '義父～梅花日記～', '不可抗力 上', '關照你的花蕾', '成化十四年', '麒麟之与子同袍', '同級生', '我爱摇滚乐', '不疯魔不成活', 'mother', '乱世为王（上卷）', '流金岁月', '圆舞', '她比烟花寂寞', '玫瑰的故事', '开到荼蘼', '承欢记', '亦舒作品集(共60册)', '人淡如菊', '寒武纪', '亦舒新经典', '乐未央', '不羁的风', '亦舒作品系列', '阿修罗', '金色梦乡', '长夜难明', '夏日启示录', '占星术杀人魔法', '首无·作祟之物', '你是我不及的梦', '傾城', '\ufeff悟空传', '明朝那些事儿（壹）', '何以笙箫默', '鬼吹灯之精绝古城', '琅琊榜', '致我们终将逝去的青春', '临高启明', '鹤唳华亭', '海棠依舊: 知否? 知否? 應是綠肥紅瘦 卷一', '怨氣撞鈴1·食骨', '\ufeff莲花', '素年锦时', '蔷薇岛屿', '眠空', '清醒纪', '八月未央', '且以永日', '安妮宝贝系列', '大方 No.1', '月', '深白', '悲伤逆流成河', '幻城', '左手倒影，右手年华。', '爵迹•燃魂书', '愿风裁尘', '临高启明', '夜旅人', '海棠依舊: 知否? 知否? 應是綠肥紅瘦 卷一', '大唐明月1·风起长安', '步步惊心', '不负如来不负卿1', '史上第一混乱·第一季神仙预备役', '扶摇皇后（上下）', '独步天下（上下卷）', '绾青丝Ⅰ', '第一风华1·天赐良缘（上下）', '官居一品（全七册）', '白马啸西风', '侠客行', '\ufeff不干了！我开除了黑心公司', '春宵苦短，少女前進吧！', '迟来的翅膀', '未聞花名（上）', '四叠半神话大系', '末日時在做什麼？有沒有空？可以來拯救嗎？ 01', '空之境界（上）', '奇诺之旅I', 'Fate/Zero Vol.1 [第四次圣杯战争秘话]', '斬首循環', '言叶之庭', '冰菓', '刀剑神域 01', '圖書館戰爭', '狼與辛香料', '少女不十分', '罗杰疑案', '死亡之犬', '幕后凶手', '阿加莎·克里斯蒂侦探推理“波洛”系列（全32册）', '告诉我，你怎样去生活', 'ABC谋杀案', '大侦探波洛精选集', '牙医谋杀案', '阳光下的罪恶', '奉命谋杀', '捕鼠器', '啤酒谋杀案', '无尽长夜', '谋杀启事', '斯泰尔斯庄园奇案', '月亮忘記了', '世界別為我擔心', '我只能為你畫一張小卡片', '\ufeff三体', '你一生的故事', '碟形世界：猫和少年魔笛手', '三体Ⅱ', '火星救援', '软件体的生命周期', '少数派报告', '深渊上的火', '\ufeff朝花惜时', '我口袋里的星辰如沙砾', '夏洛克是我的名字', '拂过冬季到云来', '这世界正在遗忘不改变的人', '七根凶简', '冰与火之歌', '大师和玛格丽特', '精灵宝钻', '哈利·波特与密室', '冰与火之歌（卷三）', '\ufeff生死桥', '她是女子，我也是女子', 'WKW', '别来无恙', '無愛紀', '霸王别姬 青蛇', '常识', '飞毡', '穿KENZO的女人', '迷楼', '月亮忘記了', ' ...
# *********************************
# 1 {'cluster_num': 1, 'key_features': ['设计', '用户', '体验', '交互', '产品'], 'books': ['杀死一只知更鸟', '杀死一只知更鸟', '杀死一只知更鸟', '杀死一只知更鸟', '认识电影', '亲密关系（第5版）', '为什么学生不喜欢上学?', '认识电影', '纽约无人是客', '写给大家看的设计书（第3版）', '素描的诀窍', '写给大家看的设计书（第3版）', '简约至上', '设计心理学', '版式设计原理', '设计的觉醒', '走进建筑师的家', '深泽直人', '西文字体', '认知与设计', '杀死一只知更鸟', '走进建筑师的家', '街道的美学', '正见', '\ufeff认识电影', '正见', '认识电影', '\ufeff素描的诀窍', '正见', '\ufeff素描的诀窍', '亲密关系（第5版）', '纽约无人是客', '纽约无人是客', '杀死一只知更鸟', '亲密关系（第5版）', '亲密关系（第5版）', '为什么学生不喜欢上学?', '摄影构图与色彩设计', '\ufeff为什么学生不喜欢上学?', '杀死一只知更鸟', '纽约无人是客', '亲密关系（第5版）', '亲密关系（第5版）', '走进世界最美的家', '住宅设计解剖书', '装修设计解剖书', '合适', '合适', '产品经理的第一本书', '简约至上', '设计心理学', '点石成金', 'About Face 3 交互设计精髓', '认知与设计', '破茧成蝶：用户体验设计师的成长之路', '人人都是产品经理', '设计师要懂心理学', 'Web界面设计', '交互设计沉思录', '触动人心', '瞬间之美', '简约至上', '设计心理学', '点石成金', 'About Face 3 交互设计精髓', '认知与设计', '破茧成蝶：用户体验设计师的成长之路', '人人都是产品经理', '设计师要懂心理学', 'Web界面设计', '交互设计沉思录', '触动人心', '瞬间之美', 'HTML & CSS设计与构建网站', '形式感+：网页视觉设计创意拓展与快速表现', '锦绣蓝图', '\ufeff点石成金', '设计心理学', 'About Face 3 交互设计精髓', '破茧成蝶：用户体验设计师的成长之路', '简约至上', '交互设计沉思录', 'Web界面设计', 'Designing Interfaces中文版', '最佳设计100细则', '移动应用UI设计模式', '用户体验度量', '形式感+：网页视觉设计创意拓展与快速表现', '用户体验面面观', '写给大家看的设计书', '\ufeffAbout Face 3 交互设计精髓', '认知与设计', '破茧成蝶：用户体验设计师的成长之路', '交互设计沉思录', '触动人心', '用户体验草图设计', '在你身边，为你设计', '用户体验面面观', '决胜UX', '设计调研', '移动设计', '亲爱的界面', 'UCD火花集', '用户体验草图设计', '用户体验面面观', '设计沟通十器', 'UCD火花集', '一目了然', '人机交互：以用户为中心的设计和评估', '就这么简单', '重塑用户体验', '体验设计白书', 'Matlab神经网络与应用', 'CSS禅意花园']}
# *********************************
# 2 {'cluster_num': 2, 'key_features': ['一个', '我们', '没有', '自己', '女人'], 'books': ['巨人的陨落', '我的前半生', '囚鸟', '月亮和六便士', '巨人的陨落', '囚鸟', '月亮和六便士', '巨人的陨落', '囚鸟', '月亮和六便士', '看见', '江城', '巨人的陨落', '小王子', '刀锋', '永恒的边缘', '白夜行', '不可思议的朋友', '怒', '来自新世界 （上下）', '现实与欲望', '\ufeff最后的精灵', '小王子', '蓝熊船长的13条半命', '爱德华的奇妙之旅', '\ufeff不可思议的朋友', '蓝熊船长的13条半命', '爷爷变成了幽灵', '爱德华的奇妙之旅', '月亮和六便士', '了不起的盖茨比', '呼啸山庄', '约翰·克利斯朵夫', '第七天', '我们生活在巨大的差距里', '没有一条道路是重复的', '红玫瑰与白玫瑰', '金锁记', '尘埃落定', '丙申故事集', '一个陌生女人的来信', '呼啸山庄', '双城记', '羊脂球', '等待戈多', '故事新编', '一个陌生女人的来信', '一个陌生女子的来信', '恐惧', '昨日之旅', '茨威格文集', '茨威格小说集', '一个陌生女人的来信', '蒙田', '好笑的爱', '玩笑', '庆祝无意义', '身份', '琴声如诉', '长别离', '劳儿之劫', '爱，谎言与写作', '直布罗陀水手', '重读', '纽约客', '\ufeff白夜行', '无人生还', '东方快车谋杀案', '猎豹', '雪人', '半落', '不可思议的朋友', '爷爷变成了幽灵', '最好的我们', '那些回不去的年少时光', '白夜行', '幻夜', '祈祷落幕时', '单恋', '银河系漫游指南', '来自新世界 （上下）', '神们自己', '三生三世 十里桃花', '他知道风从哪个方向来', '浮生若梦1', '\ufeff白夜行', '猎豹', '雪人', '怒', '达·芬奇密码', '異變者1', '萤火之森', '\ufeff魔道祖师', '桃花债', '又一春', '山河表里', '\ufeff白夜行', '东方快车谋杀案', '怒', '半落', '敲响密室之门', '万水千山走遍', '三生三世 十里桃花', '魔道祖师', '告别薇安', '大方 No.2', '瞬间空白', '爱与痛的边缘', '天亮说晚安', '刻下来的幸福时光', '庆余年·壹', '醉玲珑（上卷）', '窃明', '\ufeff东方快车谋杀案', '无人生还', '尼罗河上的惨案', '星空', '走向春天的下午', '微笑的鱼', '遗失了一只猫', '银河系漫游指南', '神们自己', '仿生人会梦见电子羊吗？', '最好的我们', '我偏爱那些不切实际的浪漫', '那些回不去的年少时光', '我知道你会来，所以我等', '哈利·波特与火焰杯', '哈利·波特与混血王子', '哈利·波特与凤凰社', '魔戒前传', '我的前半生', '喜宝', '星空', '走向春天的下午', '微笑的鱼', '遗失了一只猫', '哈利·波特与火焰杯', '哈利·波特与混血王子', '哈利·波特与凤凰社', '罪恶生涯', '一个人旅行2', '人气绘本天后高木直子作品典藏（全6册）', '一个人的第一次 第一次一个人旅行', '一个人去跑步', '楚留香传奇系列', '羽·青空之蓝', '镜·织梦者', '剩者为王Ⅱ', '文艺风象·毕业即胜利', '文艺风象·闪开！让专业不对口的来', '17', '鲤·变老', '鲤·暧昧', '鲤·最好的时光', '鲤·因爱之名', '鲤·荷尔蒙', '鲤·偶像', '\ufeff最好的我们', '忽而今夏', '我在等，等风等你来', '\ufeff人类简史', '巨人的陨落', '十二幅地图中的世界史', '少有人走的路', '自控力', '社会性动物', '非暴力沟通', '如果没有今天，明天会不会有昨天？', '人类简史', '如果没有今天，明天会不会有昨天？', '禅与摩托车维修艺术', '\ufeff人类简史', '历史深处的忧虑', '十二幅地图中的世界史', '菊与刀', '最好的告别', '社会性动物', '人类简史', '菊与刀', '看见', '\ufeff设计中的设计', '日本的八个审美意识', '做衣服', '\ufeff人类简史', '最好的告别', '江城', '历史深处的忧虑', '社会性动物', '历史深处的忧虑', '美丽新世界', '独裁者手册', '毛泽东选集 第一卷', '穆斯林的葬礼', '达·芬奇密码', '异形全书：经典四部曲终极档案', '独裁者手册', '见证', '智识分子', '毛泽东选集 第一卷', '疯癫与文明', '辛丰年音乐笔记', '\ufeff人类简史', '菊与刀', '褚时健传', '一幅画开启的世界', '如何读中国画', '等待戈多', '欲望号街车', '蒋公的面子', '玩偶之家', '如何读中国画', '雪域求法记', '亮剑', '魔鬼之师SAS', '野蛮大陆', '零年：1945', '我是女兵,也是女人', '如果没有今天，明天会不会有昨天？', '疯癫与文明', '黄泉下的美术', '奢华之色', '常识', '一幅画开启的世界', '如何看一幅画', '\ufeff我的前半生', '一个陌生女人的来信', '穆斯林的葬礼', '喜宝', '爱情和其他魔鬼', '旅行的艺术', '江城', '无声告白', '如果没有今天，明天会不会有昨天？', '少有人走的路', '无声告白', '把时间当作朋友', '我的前半生', '喜宝', '偷影子的人', '钓鱼的男孩', '所谓会说话，就是会换位思考', '\ufeff少有人走的路', '把时间当作朋友', '自控力', '别让将来的你，讨厌现在不理智的自己', '少有人走的路', '自控力', '社会性动物', '非暴力沟通', '我们时代的神经症人格', '\ufeff我的前半生', '醒来的女性', '另一座城', '\ufeff深度工作', '杜拉拉升职记', '提问的力量', '至味在人间', '孩子的宇宙', '旅行的艺术', '江城', '观呼吸', '亲密关系', '一念之转', '乳房', '病者生存', '非暴力沟通', '莉莉和章鱼', '喜宝', '我偏爱那些不切实际的浪漫', '我有个恋爱想和你谈下', '世上另一个我(修订版)', '我们为什么会分手？', '求医不如求己', '零起点学中医', '我要内脏变年轻', '黄帝内经·四气调神', '呼吸之间', '瑜伽之光', '吸引力是这样炼成的', '非暴力沟通实践篇', '我好-你好', '我把欧洲塞进背包', '伦敦', '青海/藏羚羊自助旅行手册', 'Lonely Planet旅行指南系列：韩国（2013年全新版）', '经济学通识', '定位', '精益创业', '经济学通识', '精益创业', '定位', '成为乔布斯', '公司理财', '定位', '引爆点', '无价', '精益创业', '街头生意经', '小狗钱钱', '广告文案训练手册', '定位', '创意的生成', '我们在为什么样的广告买单', '史丹·温斯坦称傲牛熊市的秘密', '规模与范围', '汽车和我', '绩效致死', '疯传', '时尚：幕后的策动', '\ufeff极简宇宙史', '人类简史', '上帝掷骰子吗', '精益创业', '上瘾', '编码的奥秘', '\ufeff极简宇宙史', '上帝掷骰子吗', '上帝的手术刀', '那些古怪又让人忧心的问题what if?', '编码的奥秘', '极简宇宙史', '迷人的材料', '支付战争', '随意搜寻']}
# *********************************
# 3 {'cluster_num': 3, 'key_features': ['历史', '一部', '小说', '金庸', '世界'], 'books': ['百年孤独', '\ufeff百年孤独', '\ufeff百年孤独', '平凡的世界（全三部）', '繁花', '黄金时代', '台北人', '\ufeff百年孤独', '艺术的故事', '平凡的世界（全三部）', '國史大綱（上下）', '挪威的森林', '世界尽头与冷酷仙境', '世界尽头与冷酷仙境', '挪威的森林', '诗的八堂课', '给孩子的诗', '天蓝色的彼岸', '黄金时代', '红拂夜奔', '青铜时代', '绿毛水怪', '白银时代', '我执', '绿山墙的安妮', '天蓝色的彼岸', '三国演义（全二册）', '叶嘉莹说汉魏六朝诗', '基督山伯爵', '傲慢与偏见', '百年孤独', '查特莱夫人的情人', '三国演义（全二册）', '罪与罚', '我没有自己的名字', '张爱玲作品集', '\ufeff夹边沟记事', '繁花', '红拂夜奔', '槐聚心史', '基督山伯爵', '傲慢与偏见', '包法利夫人', '故事新编', '三国演义（全二册）', '叶嘉莹说汉魏六朝诗', '一个政治性人物的肖像', '玛丽·斯图亚特', '情感的迷惘', '小说的艺术', '笑忘录', '被背叛的遗嘱', '广岛之恋', '写作', '毁灭，她说', '外面的世界', '小说稗类', '遗产', '塔希里亚故事集', '半小时漫画中国史（修订版）', '向左走·向右走', '松风', '\ufeff挪威的森林', '基地', '沙丘', '螺旋之谜', '天龙八部', '笑傲江湖（全四册）', '神雕侠侣', '射雕英雄传（全四册）', '鹿鼎记（全五册）', '剑桥简明金庸武侠史', '倚天屠龙记(共四册)', '金庸师承考', '陆小凤传奇', '欢乐英雄', '多情剑客无情剑(上、中、下)', '塔希里亚故事集', '\ufeff1988：我想和这个世界谈谈', '三重门', '印度墨', '盗墓笔记', '天行健（全4册）', '春宴', '临界·爵迹 I', '临界·爵迹 Ⅱ', '爵迹：雾雪零尘', '新宋', '新宋·十字1', '\ufeff天龙八部', '笑傲江湖（全四册）', '神雕侠侣', '射雕英雄传（全四册）', '鹿鼎记（全五册）', '倚天屠龙记(共四册)', '金庸江湖志', '金庸十二钗', '金庸随想录', '连城诀', '金庸师承考', '雪山飞狐', '书剑恩仇录(上下)', '飞狐外传(上下)', '剑桥简明金庸武侠史', '金庸散文集', '\ufeff向左走·向右走', '躲进世界的角落', '布瓜的世界', '基地', '沙丘', '索拉里斯星', '松风', '哈利·波特与阿兹卡班的囚徒', '哈利·波特与死亡圣器', '我执', '\ufeff向左走·向右走', '躲进世界的角落', '布瓜的世界', '哈利·波特与阿兹卡班的囚徒', '哈利·波特与死亡圣器', '哈利•波特(共6册) (精装)', '\ufeff欢乐英雄', '陆小凤传奇', '多情剑客无情剑(上、中、下)', '楚留香传奇', '三少爷的剑', '古龙作品全集（全53卷）', '笑红尘', '边城浪子（上下）', '武林外史（上下）', '镜·辟天', '三重门', '会有天使替我爱你', '万历十五年', '夹边沟记事', '黎明破晓的世界', '海洋与文明', '國史大綱（上下）', '天朝的崩溃', '大英博物馆世界简史（全3册）', '\ufeff社会心理学', '逃避自由', '进化心理学', '\ufeff哥德尔、艾舍尔、巴赫', '规训与惩罚', '社会契约论', '天外有天', '邓小平时代', '别闹了，费曼先生', '我心深处', '艺术的故事', '大英博物馆世界简史（全3册）', '忧郁的热带', '社会心理学', '忧郁的热带', '贸易的猜忌', '\ufeff艺术的故事', '大英博物馆世界简史（全3册）', '社会心理学', '邓小平时代', '一九八四·动物农场', '贸易的猜忌', '旧制度与大革命', '建构文化研究', '金刚经', '与奥逊·威尔斯共进午餐', '世界电影史', '我心深处', '贸易的猜忌', '旧制度与大革命', '社会契约论', '极权主义的起源', '变化社会中的政治秩序', '历史的终结及最后之人', '联邦党人文集', '文明的冲突与世界秩序的重建', '我的前半生', '天外有天', '\ufeff万历十五年', '夹边沟记事', '國史大綱（上下）', '天朝的崩溃', '东晋门阀政治', '中国大历史', '魏晋之际的政治权力与家族网络', '黎明破晓的世界', '进化心理学', '规训与惩罚', '國史大綱（上下）', '传习录', '论语', '经典里的中国', '黄帝内经', '来自民间的叛逆', '古典风格', '全球通史（第7版 上册）', '中国大历史', '诗的八堂课', '伊莎贝拉', '曾国藩（上中下）', '毛姆传', '曾国藩家书', '陈寅恪的最后20年', '我的前半生', '茶馆', '中央公园西路', '莎士比亚四大悲剧', '\ufeff艺术的故事', '写给大家的西方美术史', '\ufeff金刚经', '佛祖都说了些什么?', '金刚经 心经 坛经', '布局天下', '无畏之海', '中国古代战争的地理枢纽', '隐形军队', '战争改变历史', '苦难辉煌', '一战秘史', '战略', '邻人', '规训与惩罚', '\ufeff天朝的崩溃', '天国之秋', '重说中国近代史', '科举改制与最后的进士', '记忆的政治', '开放社会及其敌人（全二卷）', '联邦党人文集', '美国自由的故事', '清宫海错图', '挪威的森林', '傲慢与偏见', '带一本书去巴黎', '\ufeff社会心理学', '进化心理学', '逃避自由', '使女的故事', '雅舍谈吃', '带一本书去巴黎', '人体的故事', '吃货的生物学修养', '折纸大全', '\ufeff黄帝内经', '中央帝国的财政密码', '伟大的博弈', '策略思维', '中央帝国的财政密码', '伟大的博弈', '策略思维', '伟大的博弈', '证券分析', '证券分析', '文案发烧', '战胜华尔街', '证券分析', '文案发烧', '哥德尔、艾舍尔、巴赫', '地球之美', '众病之王', '信息简史', '哥德尔、艾舍尔、巴赫', '地球之美', '文明之光（第一册）', '信息简史', '什么是科学', '信息简史']}
# *********************************
# 4 {'cluster_num': 4, 'key_features': ['生活', '人生', '了解', '自己', '张爱玲'], 'books': ['斯通纳', '二手时间', '活着为了讲述', '斯通纳', '二手时间', '我们仨', '活着为了讲述', '我们仨', '目送', '人间草木', '瓦尔登湖', '倾城之恋', '人间草木', '智惠子抄', '\ufeff我们仨', '目送', '瓦尔登湖', '人间草木', '此生多珍重', '生活，是很好玩的', '无比芜杂的心绪', '爱吃沙拉的狮子', '事物的味道，我尝得太早了', '奥克诺斯', '智惠子抄', '恶之花', '角儿', '写在人生边上', '柑橘与柠檬啊', '古文观止', '兄弟（上）', '兄弟', '我没有自己的名字', '倾城之恋', '小团圆', '流言', '色，戒', '异乡记', '红楼梦魇', '怨女', '传奇(上下)', '张看（上下）', '棋王', '小说课', '苍老的指甲和宵遁的猫', '人情之美', '写在人生边上', '钱钟书散文', '钱钟书文集', '钱钟书杨绛散文', '古文观止', '异端的权利', '生活在别处', '\ufeff情人', '物质生活', '平静的生活', '鳄鱼手记', '天工开物·栩栩如真', '再一次', '波丽娜', '一個人住第5年', '我怎样毁了我的一生', '少年巴比伦', '秘密', '球状闪电', '那个不为人知的故事', '孤城闭', '原来你还在这里', '夜色人生', '无根之木', '吉尔莫·德尔·托罗的奇思妙想', 'PRIDE (下巻) (爆男COMICS)', '告白与告别', '通稿2003', '\ufeff我的前半生', '朝花夕拾', '夜色人生', '13．67', '哭泣的骆驼', '温柔的夜', '稻草人手记', '倾城', '那个不为人知的故事', '凤囚凰（上中）', '歌尽桃花', '三日間的幸福', '悬崖山庄奇案', '我不是完美小孩', '照相本子', '球状闪电', '每天早上和你一起醒来', '少年巴比伦', '愿你迷路到我身旁', '那个不为人知的故事', '停靠，一座城', '我有一切的美妙', '哈利·波特与魔法石', '神奇动物在哪里', '13．67', '龙头凤尾', '任你行', '原来你非不快乐', '我不是完美小孩', '照相本子', '\ufeff哈利·波特与魔法石', '哈利·波特与被诅咒的孩子', '神奇动物在哪里', '\ufeff一個人住第5年', '一个人住的每一天', '一个人漂泊的日子①', '一个人漂泊的日子2', '谁来跟我干杯', '护花铃', '听雪楼系列典藏版（全三册）', '血薇', '文艺风象·雨天爱好者', '聋哑时代', '草样年华', '二手时间', '枪炮、病菌与钢铁', '天才在左 疯子在右', '人生的智慧', '维特根斯坦传', '加缪手记', '\ufeff活着为了讲述', '维特根斯坦传', '只是孩子', '音乐使人自由', '枪炮、病菌与钢铁', '智惠子抄', '枪炮、病菌与钢铁', '二手时间', '日本新中产阶级', '二手时间', '枪炮、病菌与钢铁', '日本新中产阶级', '雕刻时光', '吉尔莫·德尔·托罗的奇思妙想', '\ufeff我们仨', '活着为了讲述', '人情之美', '时光列车', '加缪手记', '古文观止', '音乐使人自由', '如果这可以是首歌', '人间草木', '\ufeff维特根斯坦传', '穷查理宝典', '硅谷钢铁侠', '世界因你不同', '\ufeff长昼的安魂曲', '雷雨', '所有我们看不见的光', '\ufeff人生的智慧', '存在与时间', '悲剧的诞生', '倾城之恋', '智惠子抄', '情人', '泛若不系之舟', '最好金龟换酒', '人生的智慧', '刻意练习', '把力气花在你想要的生活上', '秘密', '天才在左 疯子在右', '初夜', '长恨歌', '只有医生知道!', '学会提问', '育儿基本', '泛若不系之舟', '最好金龟换酒', '秘密', '次第花开', '事事本无碍', '\ufeff只有医生知道!', '每天早上和你一起醒来', '情感暴力', '你是我的命运', 'haru的橡皮章生活', '青木和子的唯美刺绣', '问中医几度秋凉', '顾中一说：我们到底应该怎么吃？', '不要用爱控制我', '卡内基沟通与人际关系', '收纳的艺术', '家', '家事的撫慰（上冊）', '家', '住宅读本', '北欧风格小屋', '行动的勇气', '行动的勇气', '硅谷钢铁侠', '行动的勇气', '投资最重要的事', '\ufeff穷查理宝典', '投资最重要的事', '参与感', '硅谷钢铁侠', '三双鞋', '投资最重要的事', 'Neil French', '我的广告生涯&科学的广告', '蔚蓝诡计', '大量流出', '蔚蓝诡计', '超越时空', '超越时空', '赢在用户', '赢在用户', '硅谷钢铁侠', '赢在用户', '赢在用户', '赢在用户']}
# *********************************
# 5 {'cluster_num': 5, 'key_features': ['数学', '内容', '介绍', '包括', '理论'], 'books': ['鱼王', '鱼王', '鱼王', '\ufeff沉默的大多数', '浮生六记', '沉默的大多数', '心理学与生活', '经济学原理（上下）', '浮生六记', '格林童话全集', '\ufeff沉默的大多数', '\ufeff沉默的大多数', '浮生六记', '陶庵梦忆 西湖梦寻', '闲情偶寄', '麦琪的礼物', '人·兽·鬼', '麦琪的礼物', '浮生六记', '陶庵梦忆 西湖梦寻', '闲情偶寄', '地图（人文版）', '华胥引（全二册）', '冰与火之歌（卷一）', '华胥引（全二册）', '走进大文豪的家', '滚滚红尘', '华胥引（全二册）', '古书之美', '\ufeff冰与火之歌（卷一）', '心理学与生活', '理想国', '第二性', '逻辑学导论', '梵高传', '平面设计中的网格系统', '通往奴役之路', '建筑十书', '石挥谈艺录', '\ufeff数学之美', '什么是数学', '怎样解题', '概率论与数理统计', '无言的宇宙', '古今数学思想（一）', '线性代数及其应用', '思考的乐趣', '数学：确定性的丧失', '魔鬼数学', '概率论沉思录', '高观点下的初等数学', '微积分学教程（第一卷）', '数学', '离散数学及其应用（原书第5版）', '中国通史', '\ufeff沉默的大多数', '怎样欣赏音乐', '西方文明中的音乐', '梵高传', '伯里曼人体结构绘画教学', '石挥谈艺录', '楞严经', '竞逐富强', '理想国', '逻辑哲学论', '汉代物质文化资料图说', '\ufeff通往奴役之路', '一课经济学', '无政府、国家和乌托邦', '资本主义与自由', '伯里曼人体结构绘画教学', '梵高传', '透视的艺术', '心理学与生活', '人性的弱点全集', '心理学与生活', '第二性', '小强升职记', '皮革工藝. vol.9 基礎技法篇', '人体使用手册', '范志红：不懂健康，难做美丽女人', '养生书', '人情与面子', '收纳全书', '\ufeff经济学原理（上下）', '通往奴役之路', '国富论', '管理的实践', '金字塔原理', '\ufeff经济学原理（上下）', '通往奴役之路', '国富论', '\ufeff聪明的投资者', '投资中最简单的事', '货币金融学', '信用创造、货币供求与经济结构', '期货市场技术分析', '漫步华尔街', '聪明的投资者', '投资中最简单的事', '期货市场技术分析', '漫步华尔街', '消费者行为学 （第8版·中国版）', '市场营销原理', '超级符号就是超级创意', '\ufeff聪明的投资者', '投资中最简单的事', '工作前5年，决定你一生的财富', '计算广告', '超级符号就是超级创意', '投资中最简单的事', '公司价值分析', '专业投机原理', '股票大作手操盘术', '活动策划全攻略', '地图（人文版）', '什么是数学', '数学之美', '启示录', '\ufeff计算机程序的构造和解释', '编码', 'C程序设计语言', '算法导论（原书第2版）', '算法（第4版）', '编程珠玑', '程序员的自我修养', '控制论与科学方法论', '什么是数学', '七堂极简物理课', '数学之美', '\ufeff启示录', '\ufeff启示录', '\ufeff计算机程序的构造和解释', '数学之美', '机器学习', '编码', '算法导论（原书第2版）', '算法（第4版）', 'C程序设计语言', '编程珠玑', '程序员的自我修养', '编译原理', '编程之美', '图解HTTP', 'JAVASCRIPT权威指南(第四版)', 'Flask Web开发：基于Python的Web应用开发实战', '高性能JavaScript', '构建高性能Web站点', 'PHP和MySQL Web开发(原书第4版)', 'Web前端黑客技术揭秘', '文明之光（第四册）', '大话无线通信', '大话通信', '信号与系统', '无线通信', '大话移动通信', '通信原理', '数据通信与网络', '通信原理', '通信行业求职宝典', '射频和无线技术入门', '通信新读', '信息论基础', '数字通信', '数字通信', '通信之美', '数字通信', 'UCD火花集2', '神经网络与机器学习（原书第3版）', '模式识别与神经网络', '神经网络在应用科学和工程中的应用', '神经计算原理', '神经网络模型及其MATLAB仿真程序设计', '深度学习', '神经网络', '脑的高级功能与神经网络', 'MATLAB神经网络原理与实例精解', '计算机程序设计艺术（第1卷）', 'C专家编程', '程序员的自我修养', 'C程序设计语言', 'Effective java 中文版（第2版）', '高性能网站建设指南', 'Programming Ruby中文版', 'JAVASCRIPT语言精髓与编程实践']}
# *********************************
# 6 {'cluster_num': 6, 'key_features': ['艺术', '编辑', '推荐', '漫画', '畅销'], 'books': ['雪落香杉树', '戴上手套擦泪', '雪落香杉树', '戴上手套擦泪', '灯塔', '雪落香杉树', '步履不停', '亲爱的安德烈', '文学回忆录（全2册）', '活着本来单纯', '一句顶一万句', '冷暴力', '不思议图书馆', '活着本来单纯', '\ufeff一只狼在放哨', '三十而立', '幻想图书馆', '普通读者', '牡丹亭', '唐宋词十七讲', '简爱', '悲惨世界（上中下）', '一句顶一万句', '简爱', '悲惨世界（上中下）', '牡丹亭', '唐宋词十七讲', '昨日的世界', '帷幕', '相遇', '阿涅丝的最后一个下午', '米兰·昆德拉传', '欲望玫瑰', '深夜食堂 01', '封闭式车库', '画的秘密', '方向', '阿兰的战争', '守望者 上', '我可以咬一口吗', '一日谈', '卢浮宫的守护者', '嫌疑人X的献身', '幽灵', '希腊棺材之谜', '\ufeff你今天真好看', '我可以咬一口吗', '画的秘密', '生活三部曲：生活的样子', '嫌疑人X的献身', '永恒的终结', '神经漫游者', '封闭式车库', '雪落香杉树', '嫌疑人X的献身', '幽灵', '直到那一天', '有匪3', '魔戒', '二代目归来', '魔法坏女巫', '可爱的洪水猛兽', '嫌疑人X的献身', '希腊棺材之谜', '七月与安生', '小时代1.5·青木时代VOL.1', '雪落香杉树', '我的心中每天开出一朵花', '我的世界都是你', '永恒的终结', '神经漫游者', '魔法坏女巫', '魔戒', '我的心中每天开出一朵花', '我的世界都是你', '有生之年', '史记（全十册）', '冷暴力', '爱的艺术', '灯塔', '方向', '爱的艺术', '作为意志和表象的世界', '昨日的世界', '文学回忆录（全2册）', '娱乐至死', '美的历程', '狂热分子', '社会学的想像力', '脸的历史', '美的历程', '大都会艺术博物馆指南', '现代艺术150年', '认识艺术（全彩插图第8版）', '画的秘密', '孤独之间', '渴望风流', '娱乐至死', '狂热分子', '社会学的想像力', '僧侣与哲学家', '贾想1996—2008', '电影艺术（插图第8版）', '伟大的电影', '狂热分子', '昨日的世界', '山居杂忆（插图精装版）', '史记（全十册）', '作为意志和表象的世界', '哲学的故事', '僧侣与哲学家', '庄子', '史记（全十册）', '创造乡村音乐', '认识乐理', '文学回忆录（全2册）', '孤独之间', '永山裕子的水彩课', '小顾聊绘画·壹', '大都会艺术博物馆指南', '阿部智幸的水彩笔记', '永山裕子的水彩课', '渴望风流', '简·海恩斯的写意水彩', '名画之谜·希腊神话篇', '芭巴拉少校', '脸的历史', '大都会艺术博物馆指南', '现代艺术150年', '孤独之间', '现代主义', '詹森艺术史（插图第7版）', '加德纳艺术通史', '认识艺术（全彩插图第8版）', '自制美学', '风景与记忆', '艺术通史', '图说中国绘画史', '西藏度亡经', '僧侣与哲学家', '再度觉醒', '阿兰的战争', '若非此时，何时？', '作为意志和表象的世界', '哲学的故事', '什么是批判？/ 自我的文化', '\ufeff神祇、陵墓与学者', '花舞大唐春', '自由选择', '自由秩序原理', '詹森艺术史（插图第7版）', '加德纳艺术通史', '永山裕子的水彩课', '爱的艺术', '面纱', '厨艺的常识', '靠谱', '冷暴力', '爱的艺术', '摄影师', '面纱', '爱这个世界', '靠谱', '横向领导力', '斜杠创业家', '权力与领导（第5版）', '沟通圣经', '说话就是生产力', '内向者沟通圣经', '12个工作的基本', '\ufeff厨艺的常识', '食帖·真的，烤箱什么都能做', '民国太太的厨房', '四季家之味', '深夜食堂 01', '亲爱的安德烈', '孩子，把你的手给我', '酸痛拉筋解剖书', '植物性饮食革命', '爱的艺术', '植物性饮食革命', '沟通圣经', '这样装修省大钱（插图修订版）', '自由选择', '怪诞行为学', '重新定义公司', '靠谱', '商业模式新生代', '10人以下小团队管理手册', '自由选择', '怪诞行为学', '重新定义公司', '畅销的原理', '商业模式新生代', '重新定义公司', '中产阶级如何保护自己的财富', '学会花钱', '编辑力', '编辑人的世界', '时间简史', '万物：创世', '重新定义公司', '时间简史', '万物：创世', 'JavaScript DOM编程艺术', '重新定义公司', 'JavaScript DOM编程艺术']}
# *********************************
# *********************************
# 8 {'cluster_num': 8, 'key_features': ['中国', '著名', '建筑', '本书', '公司'], 'books': ['霍乱时期的爱情', '1984', '围城', '1984', '外婆的道歉信', '霍乱时期的爱情', '1984', '外婆的道歉信', '霍乱时期的爱情', '红楼梦', '围城', '北鸢', '白鹿原', '红楼梦', '围城', '山海经全译', '中国历代政治得失', '月光落在左手上', '摇摇晃晃的人间', '东宫·西宫', '佛祖在一号线', '写在人生边上 人生边上的边上 石语', '给孩子的故事', '\ufeff红楼梦', '山海经全译', '人间词话', '诗词会意：周汝昌评点中华好诗词', '山海经', '\ufeff红楼梦', '四世同堂', '第一炉香', '北鸢', '\ufeff围城', '写在人生边上 人生边上的边上 石语', '谈艺录', '围城 / 人·兽·鬼', '容安馆札记', '钱锺书手稿集•中文笔记', '钱钟书选集·散文卷，小说诗歌卷', '旧文四篇', '阿Q正传', '伤逝', '鲁迅与当代中国', '\ufeff红楼梦', '山海经全译', '人间词话', '诗词会意：周汝昌评点中华好诗词', '山海经', '中国北方的情人', '恶意', '福尔摩斯探案全集（上中下）', '塞拉菲尼抄本', '余生，请多指教', '恶意', '三体全集', '\ufeff有匪1', '偏爱你的甜', '11处特工皇妃', '\ufeff有匪1', '塞拉菲尼抄本', '恶意', '有匪1', '11处特工皇妃', '\ufeff11处特工皇妃', '三体全集', '中国历代政治得失', '叫魂', '丝绸之路', '乌合之众', '乡土中国', '丝绸之路', '乡土中国', '叫魂', '乌合之众', '中国国家治理的制度逻辑', '造房子', '造房子', '乌合之众', '乡土中国', '寻路中国', '1984', '\ufeff1984', '中国历代政治得失', '\ufeff造房子', '穿墙透壁', '中国建筑史', '华夏意匠', '建筑：形式、空间和秩序', '图像中国建筑史', '中国古代建筑史', '负建筑', '空谷幽兰', '八万四千问', '中国国家治理的制度逻辑', '论自由', '巨流河', '上学记', '中国历代政治得失', '中国近代史', '山月记', '姚著中国史', '中国历代政治得失', '中国文化的深层结构', '论自由', '中国哲学简史', '\ufeff人间词话', '中国古代文化常识', '中国文化要义', '说文解字', '给孩子的故事', '李鸿章传', '沿着塞纳河到翡冷翠', '隔江山色', '隔江山色', '维摩诘经', '中国近代史', '中国1945', '李鸿章传', '中国近代史', '近代中国社会的新陈代谢', '潮来潮去', '档案中的历史', '美术、神话与祭祀', '从历史中醒来', '中国天文考古学', '中国古代物质文化', '中国青铜时代', '唐风吹拂撒马尔罕', '暗流', '何以中国', '白沙宋墓', '中国古代壁画 唐代', '论自由', '自由与繁荣的国度', '中国美术史讲座', '霍乱时期的爱情', '\ufeff寻路中国', '沿着塞纳河到翡冷翠', '有匪1', '乌合之众', '火车上的中国人', '我爱这哭不出来的浪漫', '昨天的中国', '记忆的性别', '给孩子的故事', '\ufeff寻路中国', '沿着塞纳河到翡冷翠', '中国居民膳食指南', '\ufeff外婆的道歉信', '中国古代房内考', '人情、面子与权力的再生产', '100元狂走中国', '2011中国自助游全新彩色升级版', '中国古镇游', '大国大城', '创业维艰', '营销管理', '大败局', '大国大城', '创业维艰', '腾讯传', '大败局', '价值评估', '巴菲特致股东的信', '价值评估', '炒股的智慧', '股市真规则', '营销管理', '增长黑客', '史玉柱自述', '\ufeff创业维艰', '增长黑客', '腾讯传', '解读基金', '炒股的智慧', '巴菲特致股东的信', '炒股的智慧', '股市真规则', '巴菲特致股东的信', '腾讯传', '大败局', '中国的大企业', '非常营销：娃哈哈--中国成功的实战教案', '解构德隆', '广告人手记', '电视节目策划笔记', '创业维艰', '必然', '腾讯传', '增长黑客', '必然', '文明之光 （第三册）', '文明之光（第二册）']}
# *********************************
# 9 {'cluster_num': 9, 'key_features': ['故事', '讲述', '真实', '一个', '生活'], 'books': ['追风筝的人', '房思琪的初戀樂園', '双峰: 神秘史', '追风筝的人', '飘', '追风筝的人', '房思琪的初戀樂園', '双峰: 神秘史', '送你一颗子弹', '这些人，那些事', '撒哈拉的故事', '皮囊', '送你一颗子弹', '明朝那些事儿（1-9）', '飘', '咖啡未冷前', '这些人，那些事', '撒哈拉的故事', '皮囊', '夏洛的网', '当世界年纪还小的时候', '彼得·潘', '安吉拉·卡特的精怪故事集', '万寿寺', '黑铁时代', '窗边的小豆豆', '我亲爱的甜橙树', '夏洛的网', '草房子', '当世界年纪还小的时候', '彼得·潘', '金瓶梅', '大好河山可骑驴', '飘', '荆棘鸟', '老人与海', '红与黑', '许三观卖血记', '动物凶猛', '\ufeff飘', '老人与海', '红与黑', '巴黎圣母院', '金瓶梅', '大好河山可骑驴', '\ufeff人类的群星闪耀时', '象棋的故事', '一个陌生女人的来信', '\ufeff不能承受的生命之轻', '杜拉斯谈杜拉斯', '杜拉斯传', '孤獨，或類似的東西', '玫瑰的名字', '清明上河图密码', '放学后', '这些都是你给我的爱', '秘密花园', '我不喜欢这世界，我只喜欢你', '一个人的好天气', '此间的少年', '从你的全世界路过', '动物凶猛', '1995-2005夏至未至', '坏一坏', '微微一笑很倾城', '沉睡的人鱼之家', '放学后', '浪花少年侦探团', '三体Ⅲ', '献给阿尔吉侬的花束', '海伯利安', '微微一笑很倾城', '完美爱情标本店', '曾有一个人，爱我如生命', '双峰: 神秘史', '清明上河图密码', '清明上河图密码4', '香水', '英雄志（全三册）', '草原动物园', '灌篮高手31', '铳梦', '像少年啦飞驰', '如果墙会说话', '她的二三事', '吃南瓜的人', '放学后', '一朵桔梗花', '清明上河图密码4', '\ufeff撒哈拉的故事', '梦里花落知多少', '荷西 我爱你', '雨季不再来', '三毛典藏全集', '送你一匹马', '我的宝贝', '闹学记', '我的灵魂骑在纸背上', '流星雨', '明朝那些事儿（1-9）', '此间的少年', '彼岸花', '二三事', '素年锦时之月棠记', '\ufeff1995-2005夏至未至', '梦里花落知多少', '小时代1.0折纸时代', '小时代2.0虚铜时代', '小时代3.0：刺金时代', '夏至未至', '小时代1.5·青木时代VOL.2', '渴望死亡的小丑', '古书堂事件手帖 01', '地下铁', '我的错都是大人的错', '谢谢你毛毛兔，这个下午真好玩', '三体Ⅲ', '海伯利安', '十六夜膳房', '1995-2005夏至未至', '我还是很喜欢你', '请你永远记得我', '最初不过你好', '魔戒（第一部）', '冰与火之歌（卷二）', '青蛇', '地下铁', '我的错都是大人的错', '谢谢你毛毛兔，这个下午真好玩', '天涯·明月·刀', '年华是无效信', '鲤·嫉妒', '樱桃之远', '誓鸟', '十爱', '葵花走失在1890', '此间的少年', '微微一笑很倾城', '我们纯真的青春', '年华是无效信', '明朝那些事儿（1-9）', '人类的群星闪耀时', '送你一颗子弹', '乡下人的悲歌', '天真的人类学家', '如花在野', '房思琪的初戀樂園', '美丽灵魂', '我的应许之地', '北京的城墙与城门', '耶路撒冷三千年', '我的应许之地', '千面英雄', '故事', '剧本', '电影镜头设计', '乡下人的悲歌', '乐之本事', '人类的群星闪耀时', '天真的人类学家', '我也有一个梦想', '人类的群星闪耀时', '鞋狗', '秘密花园', '奥狄浦斯王', '莎乐美', '当和尚遇到钻石', '滑铁卢', '奥斯维辛', '五个人的战争', '像自由一样美丽', '解体概要', '袁氏当国', '与废墟为伴', '致命的自负', '飘', '平如美棠', '荆棘鸟', '夜航西飞', '撒哈拉的故事', '乖，摸摸头', '罗摩桥', '平如美棠', '皮囊', '遇见未知的自己', '如花在野', '\ufeff追风筝的人', '皮囊', '富爸爸，穷爸爸', '布鲁克林有棵树', '滚蛋吧!肿瘤君', '你不用假装过得很好', '哈佛商学院谈判课', '家庭日记', '房思琪的初戀樂園', '他们说，我是幸运的', '汪曾祺谈吃', '窗边的小豆豆', '夜航西飞', '撒哈拉的故事', '乖，摸摸头', '罗摩桥', '\ufeff遇见未知的自己', '这书能让你戒烟', '恋人絮语', '爱得太多的女人', '原谅石', '请你永远记得我', '\ufeff巧手折一折', '\ufeff如何在爱中修行', '中国自助游', '明天就去尼泊尔', '经济学的思维方式（第11版）', '致命的自负', '经济学的思维方式（第11版）', '致命的自负', '哈佛商学院谈判课', '鞋狗', '富爸爸，穷爸爸', '世界上最伟大的推销员', '鞋狗', '精益创业实战', '富爸爸，穷爸爸', 'The Copy Book 全球32位顶尖广告文案的写作之道', '创意', '光变：一个企业及其工业史', '迪斯尼战争', '\ufeff创意', '会讲故事，让世界听你的', '創意筆記本: 概念力', '集体智慧编程', '万物简史', '交互设计之路', 'Web表单设计', '交互设计之路', 'Web表单设计', '集体智慧编程', '交互设计之路', 'Web表单设计', '交互设计之路', 'Web表单设计']}
# *********************************

# %%
def print_cluster_data(cluster_data):
    # print cluster details
    for cluster_num, cluster_details in cluster_data.items():
        print('Cluster {} details:'.format(cluster_num))
        print('-' * 20)
        print('Key features:', cluster_details['key_features'])
        print('book in this cluster:')
        print(', '.join(cluster_details['books']))
        print('=' * 40)

# %%
cluster_data = get_cluster_data(clustering_obj=km_obj,
                                book_data=book_data,
                                feature_names=feature_names,
                                num_clusters=num_clusters,
                                topn_features=5
                               )
print_cluster_data(cluster_data)
# Out:
# Cluster 0 details:
# --------------------
# Key features: ['本书', '一本', 'the', '不是', '出版']
# book in this cluster:
# ========================================
# Cluster 1 details:
# --------------------
# Key features: ['设计', '用户', '体验', '交互', '产品']
# book in this cluster:
# 杀死一只知更鸟, 杀死一只知更鸟, 杀死一只知更鸟, 杀死一只知更鸟, 认识电影, 亲密关系（第5版）, 为什么学生不喜欢上学?, 认识电影, 纽约无人是客, 写给大家看的设计书（第3版）, 素描的诀窍, 写给大家看的设计书（第3版）, 简约至上, 设计心理学, 版式设计原理, 设计的觉醒, 走进建筑师的家, 深泽直人, 西文字体, 认知与设计, 杀死一只知更鸟, 走进建筑师的家, 街道的美学, 正见, ﻿认识电影, 正见, 认识电影, ﻿素描的诀窍, 正见, ﻿素描的诀窍, 亲密关系（第5版）, 纽约无人是客, 纽约无人是客, 杀死一只知更鸟, 亲密关系（第5版）, 亲密关系（第5版）, 为什么学生不喜欢上学?, 摄影构图与色彩设计, ﻿为什么学生不喜欢上学?, 杀死一只知更鸟, 纽约无人是客, 亲密关系（第5版）, 亲密关系（第5版）, 走进世界最美的家, 住宅设计解剖书, 装修设计解剖书, 合适, 合适, 产品经理的第一本书, 简约至上, 设计心理学, 点石成金, About Face 3 交互设计精髓, 认知与设计, 破茧成蝶：用户体验设计师的成长之路, 人人都是产品经理, 设计师要懂心理学, Web界面设计, 交互设计沉思录, 触动人心, 瞬间之美, 简约至上, 设计心理学, 点石成金, About Face 3 交互设计精髓, 认知与设计, 破茧成蝶：用户体验设计师的成长之路, 人人都是产品经理, 设计师要懂心理学, Web界面设计, 交互设计沉思录, 触动人心, 瞬间之美, HTML & CSS设计与构建网站, 形式感+：网页视觉设计创意拓展与快速表现, 锦绣蓝图, ﻿点石成金, 设计心理学, About Face 3 交互设计精髓, 破茧成蝶：用户体验设计师的成长之路, 简约至上, 交互设计沉思录, Web界面设计, Designing Interfaces中文版, 最佳设计100细则, 移动应用UI设计模式, 用户体验度量, 形式感+：网页视觉设计创意拓展与快速表现, 用户体验面面观, 写给大家看的设计书, ﻿About Face 3 交互设计精髓, 认知与设计, 破茧成蝶：用户体验设计师的成长之路, 交互设计沉思录, 触动人心, 用户体验草图设计, 在你身边，为你设计, 用户体验面面观, 决胜UX, 设计调研, 移动设计, 亲爱的界面, UCD火花集, 用户体验草图设计, 用户体验面面观, 设计沟通十器, UCD火花集, 一目了然, 人机交互：以用户为中心的设计和评估, 就这么简单, 重塑用户体验, 体验设计白书, Matlab神经网络与应用, CSS禅意花园
# ========================================
# Cluster 2 details:
# --------------------
# Key features: ['一个', '我们', '没有', '自己', '女人']
# book in this cluster:
# 巨人的陨落, 我的前半生, 囚鸟, 月亮和六便士, 巨人的陨落, 囚鸟, 月亮和六便士, 巨人的陨落, 囚鸟, 月亮和六便士, 看见, 江城, 巨人的陨落, 小王子, 刀锋, 永恒的边缘, 白夜行, 不可思议的朋友, 怒, 来自新世界 （上下）, 现实与欲望, ﻿最后的精灵, 小王子, 蓝熊船长的13条半命, 爱德华的奇妙之旅, ﻿不可思议的朋友, 蓝熊船长的13条半命, 爷爷变成了幽灵, 爱德华的奇妙之旅, 月亮和六
（卷一）, 心理学与生活, 理想国, 第二性, 逻辑学导论, 梵高传, 平面设计中的网格系统, 通往奴役之路, 建筑十书, 石挥谈艺录, ﻿数学之美, 什么是数学, 怎样解题, 概率论与数理统计, 无言的宇宙, 古今数学思想（一）, 线性代数及其应用, 思考的乐趣, 数学：确定性的丧失, 魔鬼数学, 概率论沉思录, 高观点下的初等数学, 微积分学教程（第一卷）, 数学, 离散数学及其应用（原书第5版）, 中国通史, ﻿沉默的大多数, 怎样欣赏音乐, 西方文明中的音乐, 梵高传, 伯里曼人体结构绘画教学, 石挥谈艺录, 楞严经, 竞逐富强, 理想国, 逻辑哲学论, 汉代物质文化资料图说, ﻿通往奴役之路, 一课经济学, 无政府、国家和乌托邦, 资本主义与自由, 伯里曼人体结构绘画教学, 梵高传, 透视的艺术, 心理学与生活, 人性的弱点全集, 心理学与生活, 第二性, 小强升职记, 皮革工藝. vol.9 基礎技法篇, 人体使用手册, 范志红：不懂健康，难做美丽女人, 养生书, 人情与面子, 收纳全书, ﻿经济学原理（上下）, 通往奴役之路, 国富论, 管理的实践, 金字塔原理, ﻿经济学原理（上下）, 通往奴役之路, 国富论, ﻿聪明的投资者, 投资中最简单的事, 货币金融学, 信用创造、货币供求与经济结构, 期货市场技术分析, 漫步华尔街, 聪明的投资者, 投资中最简单的事, 期货市场技术分析, 漫步华尔街, 消费者行为学 （第8版·中国版）, 市场营销原理, 超级符号就是超级创意, ﻿聪明的投资者, 投资中最简单的事, 工作前5年，决定你一生的财富, 计算广告, 超级符号就是超级创意, 投资中最简单的事, 公司价值分析, 专业投机原理, 股票大作手操盘术, 活动策划全攻略, 地图（人文版）, 什么是数学, 数学之美, 启示录, ﻿计算机程序的构造和解释, 编码, C程序设计语言, 算法导论（原书第2版）, 算法（第4版）, 编程珠玑, 程序员的自我修养, 控制论与科学方法论, 什么是数学, 七堂极简物理课, 数学之美, ﻿启示录, ﻿启示录, ﻿计算机程序的构造和解释, 数学之美, 机器学习, 编码, 算法导论（原书第2版）, 算法（第4版）, C程序设计语言, 编程珠玑, 程序员的自我修养, 编译原理, 编程之美, 图解HTTP, JAVASCRIPT权威指南(第四版), Flask Web开发：基于Python的Web应用开发实战, 高性能JavaScript, 构建高性能Web站点, PHP和MySQL Web开发(原书第4版), Web前端黑客技术揭秘, 文明之光（第四册）, 大话无线通信, 大话通信, 信号与系统, 无线通信, 大话移动通信, 通信原理, 数据通信与网络, 通信原理, 通信行业求职宝典, 射频和无线技术入门, 通信新读, 信息论基础, 数字通信, 数字通信, 通信之美, 数字通信, UCD火花集2, 神经网络与机器学习（原书第3版）, 模式识别与神经网络, 神经网络在应用科学和工程中的应用, 神经计算原理, 神经网络模型及其MATLAB仿真程序设计, 深度学习, 神经网络, 脑的高级功能与神经网络, MATLAB神经网络原理与实例精解, 计算机程序设计艺术（第1卷）, C专家编程, 程序员的自我修养, C程序设计语言, Effective java 中文版（第2版）, 高性能网站建设指南, Programming Ruby中文版, JAVASCRIPT语言精髓与编程实践
# ========================================
# Cluster 6 details:
# --------------------
